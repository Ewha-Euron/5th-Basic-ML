# %% [markdown]
# Importing Libraries and Reading the Dataset
# winequality-red.csv의 데이터를 가져옴
#
# Data Visualization and Preprocessing
# 'quality'에 따른 데이터 세트 분류
# plt.xticks(range(len(corr.columns)), corr.columns), plt.yticks(range(len(corr.columns)), corr.columns)로 data 표로 보기
#
# Classification Models
#
# Logistic Regression
# 로지스틱 회귀로 데이터 훈련
# Cross Validation Score 예측
#
# K-Nearest Neighbors(K-NN)
# KNN을 통한 데이터 훈련
#
# Support Vector Machine (SVM - Linear)
# SVM을 통한 데이터 훈련
# Support Vector Machine (SVM - Kernel)
#
# Naive Bayes
#
# Decision Tree Classification
# 결정 트리 모델을 통한 데이터 훈련
#
# Random Forest Classification
# 랜덤 포레스트 모델을 통한 데이터 훈련
#
# Measuring the Error
# 각각의 모델에서 True Positive	False Positive	True Negative	False Negative	Accuracy(training)	Accuracy(test)	Cross-Validation 값 예측
#
# Visualizing Models Performance
# axes[0].set(xlabel='Region', ylabel='Charges')를 통한 모델 행동 보기
